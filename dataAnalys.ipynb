# %%
import scipy.io

var = scipy.io.loadmat("data//avenue//vol01.mat")

# %%
print(var.keys())
print("test")
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'vol'])
# test

# %%
siffror = var["vol"]

# %%
import matplotlib.pyplot as plt
import cv2
plt.imshow(cv2.cvtColor( siffror[:,:,1000],cv2.COLOR_RGB2BGR))

plt.show()

# %%
import matplotlib.pyplot as plt
import cv2

bild = cv2.imread("data\ped2//training//frames//01//000.jpg")
plt.imshow(bild)
